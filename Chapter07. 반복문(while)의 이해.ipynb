# %% [markdown]
# ## 학습목표
# - 반복문의 이해 및 활용(while)

# %% [markdown]
# ### loop(반복문)
# - 반복적인 작업을 가능하게 해주는 도구
# - 특정 조건을 만족하는 경우 수행할 수 있음(while)
# - 리스트, 문자열, 튜플 등 컬렉션 타입의 아이템을 하나씩 순회하면서 사용 가능(for)
# - 코드 작업에서, 가장 많이 사용하는 구문 중 하나
# - 주의할점: while을 사용할 경우, 반복을 멈추게 하는 장치가 필요
#     - 그렇지 않으면 셀이 무한히 수행되며, jupyter notebook의 재부팅이 필요

# %% [markdown]
# ### while 키워드
# - while 뒤의 조건이 True일 경우, while코드 블록을 계속 수행
# - while 코드블록
#     - if와 마찬가지로 while문 아래의 들여쓰기로 작성된 부분을 의미
# - 조건이 False가 되면 블록 수행을 멈추고 이후 코드를 수행

# %% [markdown]
# ### while 키워드 이용하여 리스트의 아이템 출력하기

# %%
a = [1, 10, 9, 23, 566, 23, 45, 67, 89]

index = 0
while index < len(a):
    print('value: ' , a[index], ', index: ', index)
    index += 1

print('hahah')
# Out:
# value:  1 , index:  0
# value:  10 , index:  1
# value:  9 , index:  2
# value:  23 , index:  3
# value:  566 , index:  4
# value:  23 , index:  5
# value:  45 , index:  6
# value:  67 , index:  7
# value:  89 , index:  8
# hahah

# %% [markdown]
# ### while 키워드 이용하여 리스트의 아이템 출력하기
# - 조건문과 함께 사용하기

# %%
a = [1, 10, 9, 23, 566, 23, 45, 67, 89, 25, 26]

index = 0
while index < len(a):
    if a[index] > 20: # 20보다 큰 경우만 출력
        print(a[index])
    index += 1
# Out:
# 23
# 566
# 23
# 45
# 67
# 89
# 25
# 26

# %%
a = [1, 10, 9, 23, 566, 23, 45, 67, 89, 25, 26]

index = 0
while index < len(a):
    if a[index] % 2: # 홀수인 경우만 출력
        print(a[index])
    else:
        print(a[index] / 2)
    index += 1
# Out:
# 1
# 5.0
# 9
# 23
# 283.0
# 23
# 45
# 67
# 89
# 25
# 13.0

# %% [markdown]
# ### 무한루프
# - while의 경우 종류되지 않도록 코드를 작성하면 블록에서 빨져나올 수 없음

# %%
# while True:
#     print('hahahaha')

# %% [markdown]
# ### break
# - loop를 중단할 때 사용
# - 보통 조건문 안에서 수행되며, 조건을 만족하는 경우 loop를 탈출하기 위해 사용
# - loop를 중단하는 경우, while 이후의 코드를 수행

# %%
a = [1, 10, 9, 23, 566, 23, 45, 67, 89, 25, 26]

index = 0
while index < len(a):
    if a[index] > 20:
        break

    print(a[index])
    index += 1

print('hahah')
# Out:
# 1
# 10
# 9
# hahah

# %% [markdown]
# ### continue
# - break처럼 반복을 중단하여 빠져나오지 않고, 다시 while 조건으로 점프함
# - 특정한 경우에는 코드를 수행하지 않고 다음으로 건너뛰기 위해 사용

# %%
a = 7

while a > 0 :
    a -= 1
    if a == 5:
        continue
    print(a)
# Out:
# 6
# 4
# 3
# 2
# 1
# 0

# %% [markdown]
# ### 1부터 100까지 더하기

# %%
_sum = 0
num = 1
while num <= 100:
    _sum += num
    num += 1

print('sum : ', _sum)
# Out:
# sum :  5050
